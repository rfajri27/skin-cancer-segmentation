# %% [markdown]
# ## Download the Dataset

# %%
import gdown

dataset_link = 'https://drive.google.com/file/d/1E5P7Wt-2I40eb4qhKL3zjwB_LfnYtWkW/view?usp=share_link'#@param {type:"string"}
id = dataset_link.split('/')[-2]

link = 'https://drive.google.com/u/0/uc?id=' + id + '&export=download'
output = 'dataset.zip'

gdown.download(link, output, quiet=False)

# !unzip 'dataset.zip' -d 'dataset'
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1E5P7Wt-2I40eb4qhKL3zjwB_LfnYtWkW&export=download
# To: /content/dataset.zip
# 100%|██████████| 2.78G/2.78G [00:35<00:00, 78.9MB/s]
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/masks/ISIC_0029321_segmentation.png
#   inflating: dataset/masks/ISIC_0029322_segmentation.png
#   inflating: dataset/masks/ISIC_0029323_segmentation.png
#   inflating: dataset/masks/ISIC_0029324_segmentation.png
#   inflating: dataset/masks/ISIC_0029325_segmentation.png
#   inflating: dataset/masks/ISIC_0029326_segmentation.png
#   inflating: dataset/masks/ISIC_0029327_segmentation.png
#   inflating: dataset/masks/ISIC_0029328_segmentation.png
#   inflating: dataset/masks/ISIC_0029329_segmentation.png
#   inflating: dataset/masks/ISIC_0029330_segmentation.png
#   inflating: dataset/masks/ISIC_0029331_segmentation.png
#   inflating: dataset/masks/ISIC_0029332_segmentation.png
#   inflating: dataset/masks/ISIC_0029333_segmentation.png
#   inflating: dataset/masks/ISIC_0029334_segmentation.png
#   inflating: dataset/masks/ISIC_0029335_segmentation.png
#   inflating: dataset/masks/ISIC_0029336_segmentation.png
#   inflating: dataset/masks/ISIC_0029337_segmentation.png
#   inflating: dataset/masks/ISIC_0029338_segmentation.png
#   inflating: dataset/masks/ISIC_0029339_segmentation.png
#   inflating: dataset/masks/ISIC_0029340_segmentation.png
#   inflating: dataset/masks/ISIC_0029341_segmentation.png
#   inflating: dataset/masks/ISIC_0029342_segmentation.png
#   inflating: dataset/masks/ISIC_0029343_segmentation.png
#   inflating: dataset/masks/ISIC_0029344_segmentation.png
#   inflating: dataset/masks/ISIC_0029345_segmentation.png
#   inflating: dataset/masks/ISIC_0029346_segmentation.png
#   inflating: dataset/masks/ISIC_0029347_segmentation.png
#   inflating: dataset/masks/ISIC_0029348_segmentation.png
#   inflating: dataset/masks/ISIC_0029349_segmentation.png
#   inflating: dataset/masks/ISIC_0029350_segmentation.png
#   inflating: dataset/masks/ISIC_0029351_segmentation.png
#   inflating: dataset/masks/ISIC_0029352_segmentation.png
#   inflating: dataset/masks/ISIC_0029353_segmentation.png
#   inflating: dataset/masks/ISIC_0029354_segmentation.png
#   inflating: dataset/masks/ISIC_0029355_segmentation.png
#   inflating: dataset/masks/ISIC_0029356_segmentation.png
#   inflating: dataset/masks/ISIC_0029357_segmentation.png
#   inflating: dataset/masks/ISIC_0029358_segmentation.png
#   inflating: dataset/masks/ISIC_0029359_segmentation.png
#   inflating: dataset/masks/ISIC_0029360_segmentation.png
#   inflating: dataset/masks/ISIC_0029361_segmentation.png
#   inflating: dataset/masks/ISIC_0029362_segmentation.png
#   inflating: dataset/masks/ISIC_0029363_segmentation.png
#   inflating: dataset/masks/ISIC_0029364_segmentation.png
#   inflating: dataset/masks/ISIC_0029365_segmentation.png
#   inflating: dataset/masks/ISIC_0029366_segmentation.png
#   inflating: dataset/masks/ISIC_0029367_segmentation.png
#   inflating: dataset/masks/ISIC_0029368_segmentation.png
#   inflating: dataset/masks/ISIC_0029369_segmentation.png
#   inflating: dataset/masks/ISIC_0029370_segmentation.png
#   inflating: dataset/masks/ISIC_0029371_segmentation.png
#   inflating: dataset/masks/ISIC_0029372_segmentation.png
#   inflating: dataset/masks/ISIC_0029373_segmentation.png
#   inflating: dataset/masks/ISIC_0029374_segmentation.png
#   inflating: dataset/masks/ISIC_0029375_segmentation.png
#   inflating: dataset/masks/ISIC_0029376_segmentation.png
#   inflating: dataset/masks/ISIC_0029377_segmentation.png
#   inflating: dataset/masks/ISIC_0029378_segmentation.png
#   inflating: dataset/masks/ISIC_0029379_segmentation.png
#   inflating: dataset/masks/ISIC_0029380_segmentation.png
#   inflating: dataset/masks/ISIC_0029381_segmentation.png
#   inflating: dataset/masks/ISIC_0029382_segmentation.png
#   inflating: dataset/masks/ISIC_0029383_segmentation.png
#   inflating: dataset/masks/ISIC_0029384_segmentation.png
#   inflating: dataset/masks/ISIC_0029385_segmentation.png
#   inflating: dataset/masks/ISIC_0029386_segmentation.png
#   inflating: dataset/masks/ISIC_0029387_segmentation.png
#   inflating: dataset/masks/ISIC_0029388_segmentation.png
#   inflating: dataset/masks/ISIC_0029389_segmentation.png
#   inflating: dataset/masks/ISIC_0029390_segmentation.png
#   inflating: dataset/masks/ISIC_0029391_segmentation.png
#   inflating: dataset/masks/ISIC_0029392_segmentation.png
#   inflating: dataset/masks/ISIC_0029393_segmentation.png
#   inflating: dataset/masks/ISIC_0029394_segmentation.png
#   inflating: dataset/masks/ISIC_0029395_segmentation.png
#   inflating: dataset/masks/ISIC_0029396_segmentation.png
#   inflating: dataset/masks/ISIC_0029397_segmentation.png
#   inflating: dataset/masks/ISIC_0029398_segmentation.png
#   inflating: dataset/masks/ISIC_0029399_segmentation.png
#   inflating: dataset/masks/ISIC_0029400_segmentation.png
#   inflating: dataset/masks/ISIC_0029401_segmentation.png
#   inflating: dataset/masks/ISIC_0029402_segmentation.png
#   inflating: dataset/masks/ISIC_0029403_segmentation.png
#   inflating: dataset/masks/ISIC_0029404_segmentation.png
#   inflating: dataset/masks/ISIC_0029405_segmentation.png
#   inflating: dataset/masks/ISIC_0029406_segmentation.png
#   inflating: dataset/masks/ISIC_0029407_segmentation.png
#   inflating: dataset/masks/ISIC_0029408_segmentation.png
#   inflating: dataset/masks/ISIC_0029409_segmentation.png
#   inflating: dataset/masks/ISIC_0029410_segmentation.png
#   inflating: dataset/masks/ISIC_0029411_segmentation.png
#   inflating: dataset/masks/ISIC_0029412_segmentation.png
#   inflating: dataset/masks/ISIC_0029413_segmentation.png
#   inflating: dataset/masks/ISIC_0029414_segmentation.png
#   inflating: dataset/masks/ISIC_0029415_segmentation.png
#   inflating: dataset/masks/ISIC_0029416_segmentation.png
#   inflating: dataset/masks/ISIC_0029417_segmentation.png
#   inflating: dataset/masks/ISIC_0029418_segmentation.png
#   inflating: dataset/masks/ISIC_0029419_segmentation.png
#   inflating: dataset/masks/ISIC_0029420_segmentation.png
#   inflating: dataset/masks/ISIC_0029421_segmentation.png
#   inflating: dataset/masks/ISIC_0029422_segmentation.png
#   inflating: dataset/masks/ISIC_0029423_segmentation.png
#   inflating: dataset/masks/ISIC_0029424_segmentation.png
#   inflating: dataset/masks/ISIC_0029425_segmentation.png
#   inflating: dataset/masks/ISIC_0029426_segmentation.png
#   inflating: dataset/masks/ISIC_0029427_segmentation.png
#   inflating: dataset/masks/ISIC_0029428_segmentation.png
#   inflating: dataset/masks/ISIC_0029429_segmentation.png
#   inflating: dataset/masks/ISIC_0029430_segmentation.png
#   inflating: dataset/masks/ISIC_0029431_segmentation.png
#   inflating: dataset/masks/ISIC_0029432_segmentation.png
#   inflating: dataset/masks/ISIC_0029433_segmentation.png
#   inflating: dataset/masks/ISIC_0029434_segmentation.png
#   inflating: dataset/masks/ISIC_0029435_segmentation.png
#   inflating: dataset/masks/ISIC_0029436_segmentation.png
#   inflating: dataset/masks/ISIC_0029437_segmentation.png
#   inflating: dataset/masks/ISIC_0029438_segmentation.png
#   inflating: dataset/masks/ISIC_0029439_segmentation.png
#   inflating: dataset/masks/ISIC_0029440_segmentation.png
#   inflating: dataset/masks/ISIC_0029441_segmentation.png
#   inflating: dataset/masks/ISIC_0029442_segmentation.png
#   inflating: dataset/masks/ISIC_0029443_segmentation.png
#   inflating: dataset/masks/ISIC_0029444_segmentation.png
#   inflating: dataset/masks/ISIC_0029445_segmentation.png
#   inflating: dataset/masks/ISIC_0029446_segmentation.png
#   inflating: dataset/masks/ISIC_0029447_segmentation.png
#   inflating: dataset/masks/ISIC_0029448_segmentation.png
#   inflating: dataset/masks/ISIC_0029449_segmentation.png
#   inflating: dataset/masks/ISIC_0029450_segmentation.png
#   inflating: dataset/masks/ISIC_0029451_segmentation.png
#   inflating: dataset/masks/ISIC_0029452_segmentation.png
#   inflating: dataset/masks/ISIC_0029453_segmentation.png
#   inflating: dataset/masks/ISIC_0029454_segmentation.png
#   inflating: dataset/masks/ISIC_0029455_segmentation.png
#   inflating: dataset/masks/ISIC_0029456_segmentation.png
#   inflating: dataset/masks/ISIC_0029457_segmentation.png
#   inflating: dataset/masks/ISIC_0029458_segmentation.png
#   inflating: dataset/masks/ISIC_0029459_segmentation.png
#   inflating: dataset/masks/ISIC_0029460_segmentation.png
#   inflating: dataset/masks/ISIC_0029461_segmentation.png
#   inflating: dataset/masks/ISIC_0029462_segmentation.png
#   inflating: dataset/masks/ISIC_0029463_segmentation.png
#   inflating: dataset/masks/ISIC_0029464_segmentation.png
#   inflating: dataset/masks/ISIC_0029465_segmentation.png
#   inflating: dataset/masks/ISIC_0029466_segmentation.png
#   inflating: dataset/masks/ISIC_0029467_segmentation.png
#   inflating: dataset/masks/ISIC_0029468_segmentation.png
#   inflating: dataset/masks/ISIC_0029469_segmentation.png
#   inflating: dataset/masks/ISIC_0029470_segmentation.png
#   inflating: dataset/masks/ISIC_0029471_segmentation.png
#   inflating: dataset/masks/ISIC_0029472_segmentation.png
#   inflating: dataset/masks/ISIC_0029473_segmentation.png
#   inflating: dataset/masks/ISIC_0029474_segmentation.png
#   inflating: dataset/masks/ISIC_0029475_segmentation.png
#   inflating: dataset/masks/ISIC_0029476_segmentation.png
#   inflating: dataset/masks/ISIC_0029477_segmentation.png
#   inflating: dataset/masks/ISIC_0029478_segmentation.png
#   inflating: dataset/masks/ISIC_0029479_segmentation.png
#   inflating: dataset/masks/ISIC_0029480_segmentation.png
#   inflating: dataset/masks/ISIC_0029481_segmentation.png
#   inflating: dataset/masks/ISIC_0029482_segmentation.png
#   inflating: dataset/masks/ISIC_0029483_segmentation.png
#   inflating: dataset/masks/ISIC_0029484_segmentation.png
#   inflating: dataset/masks/ISIC_0029485_segmentation.png
#   inflating: dataset/masks/ISIC_0029486_segmentation.png
#   inflating: dataset/masks/ISIC_0029487_segmentation.png
#   inflating: dataset/masks/ISIC_0029488_segmentation.png
#   inflating: dataset/masks/ISIC_0029489_segmentation.png
#   inflating: dataset/masks/ISIC_0029490_segmentation.png
#   inflating: dataset/masks/ISIC_0029491_segmentation.png
#   inflating: dataset/masks/ISIC_0029492_segmentation.png
#   inflating: dataset/masks/ISIC_0029493_segmentation.png
#   inflating: dataset/masks/ISIC_0029494_segmentation.png
#   inflating: dataset/masks/ISIC_0029495_segmentation.png
#   inflating: dataset/masks/ISIC_0029496_segmentation.png
#   inflating: dataset/masks/ISIC_0029497_segmentation.png
#   inflating: dataset/masks/ISIC_0029498_segmentation.png
#   inflating: dataset/masks/ISIC_0029499_segmentation.png
#   inflating: dataset/masks/ISIC_0029500_segmentation.png
#   inflating: dataset/masks/ISIC_0029501_segmentation.png
#   inflating: dataset/masks/ISIC_0029502_segmentation.png
#   inflating: dataset/masks/ISIC_0029503_segmentation.png
#   inflating: dataset/masks/ISIC_0029504_segmentation.png
#   inflating: dataset/masks/ISIC_0029505_segmentation.png
#   inflating: dataset/masks/ISIC_0029506_segmentation.png
#   inflating: dataset/masks/ISIC_0029507_segmentation.png
#   inflating: dataset/masks/ISIC_0029508_segmentation.png
#   inflating: dataset/masks/ISIC_0029509_segmentation.png
#   inflating: dataset/masks/ISIC_0029510_segmentation.png
#   inflating: dataset/masks/ISIC_0029511_segmentation.png
#   inflating: dataset/masks/ISIC_0029512_segmentation.png
#   inflating: dataset/masks/ISIC_0029513_segmentation.png
#   inflating: dataset/masks/ISIC_0029514_segmentation.png
#   inflating: dataset/masks/ISIC_0029515_segmentation.png
#   inflating: dataset/masks/ISIC_0029516_segmentation.png
#   inflating: dataset/masks/ISIC_0029517_segmentation.png
#   inflating: dataset/masks/ISIC_0029518_segmentation.png
#   inflating: dataset/masks/ISIC_0029519_segmentation.png
#   inflating: dataset/masks/ISIC_0029520_segmentation.png
#   inflating: dataset/masks/ISIC_0029521_segmentation.png
#   inflating: dataset/masks/ISIC_0029522_segmentation.png
#   inflating: dataset/masks/ISIC_0029523_segmentation.png
#   inflating: dataset/masks/ISIC_0029524_segmentation.png
#   inflating: dataset/masks/ISIC_0029525_segmentation.png
#   inflating: dataset/masks/ISIC_0029526_segmentation.png
#   inflating: dataset/masks/ISIC_0029527_segmentation.png
#   inflating: dataset/masks/ISIC_0029528_segmentation.png
#   inflating: dataset/masks/ISIC_0029529_segmentation.png
#   inflating: dataset/masks/ISIC_0029530_segmentation.png
#   inflating: dataset/masks/ISIC_0029531_segmentation.png
#   inflating: dataset/masks/ISIC_0029532_segmentation.png
#   inflating: dataset/masks/ISIC_0029533_segmentation.png
#   inflating: dataset/masks/ISIC_0029534_segmentation.png
#   inflating: dataset/masks/ISIC_0029535_segmentation.png
#   inflating: dataset/masks/ISIC_0029536_segmentation.png
#   inflating: dataset/masks/ISIC_0029537_segmentation.png
#   inflating: dataset/masks/ISIC_0029538_segmentation.png
#   inflating: dataset/masks/ISIC_0029539_segmentation.png
#   inflating: dataset/masks/ISIC_0029540_segmentation.png
#   inflating: dataset/masks/ISIC_0029541_segmentation.png
#   inflating: dataset/masks/ISIC_0029542_segmentation.png
#   inflating: dataset/masks/ISIC_0029543_segmentation.png
#   inflating: dataset/masks/ISIC_0029544_segmentation.png
#   inflating: dataset/masks/ISIC_0029545_segmentation.png
#   inflating: dataset/masks/ISIC_0029546_segmentation.png
#   inflating: dataset/masks/ISIC_0029547_segmentation.png
#   inflating: dataset/masks/ISIC_0029548_segmentation.png
#   inflating: dataset/masks/ISIC_0029549_segmentation.png
#   inflating: dataset/masks/ISIC_0029550_segmentation.png
#   inflating: dataset/masks/ISIC_0029551_segmentation.png
#   inflating: dataset/masks/ISIC_0029552_segmentation.png
#   inflating: dataset/masks/ISIC_0029553_segmentation.png
#   inflating: dataset/masks/ISIC_0029554_segmentation.png
#   inflating: dataset/masks/ISIC_0029555_segmentation.png
#   inflating: dataset/masks/ISIC_0029556_segmentation.png
#   inflating: dataset/masks/ISIC_0029557_segmentation.png
#   inflating: dataset/masks/ISIC_0029558_segmentation.png
#   inflating: dataset/masks/ISIC_0029559_segmentation.png
#   inflating: dataset/masks/ISIC_0029560_segmentation.png
#   inflating: dataset/masks/ISIC_0029561_segmentation.png
#   inflating: dataset/masks/ISIC_0029562_segmentation.png
#   inflating: dataset/masks/ISIC_0029563_segmentation.png
#   inflating: dataset/masks/ISIC_0029564_segmentation.png
#   inflating: dataset/masks/ISIC_0029565_segmentation.png
#   inflating: dataset/masks/ISIC_0029566_segmentation.png
#   inflating: dataset/masks/ISIC_0029567_segmentation.png
#   inflating: dataset/masks/ISIC_0029568_segmentation.png
#   inflating: dataset/masks/ISIC_0029569_segmentation.png
#   inflating: dataset/masks/ISIC_0029570_segmentation.png
#   inflating: dataset/masks/ISIC_0029571_segmentation.png
#   inflating: dataset/masks/ISIC_0029572_segmentation.png
#   inflating: dataset/masks/ISIC_0029573_segmentation.png
#   inflating: dataset/masks/ISIC_0029574_segmentation.png
#   inflating: dataset/masks/ISIC_0029575_segmentation.png
#   inflating: dataset/masks/ISIC_0029576_segmentation.png
#   inflating: dataset/masks/ISIC_0029577_segmentation.png
#   inflating: dataset/masks/ISIC_0029578_segmentation.png
#   inflating: dataset/masks/ISIC_0029579_segmentation.png
#   inflating: dataset/masks/ISIC_0029580_segmentation.png
#   inflating: dataset/masks/ISIC_0029581_segmentation.png
#   inflating: dataset/masks/ISIC_0029582_segmentation.png
#   inflating: dataset/masks/ISIC_0029583_segmentation.png
#   inflating: dataset/masks/ISIC_0029584_segmentation.png
#   inflating: dataset/masks/ISIC_0029585_segmentation.png
#   inflating: dataset/masks/ISIC_0029586_segmentation.png
#   inflating: dataset/masks/ISIC_0029587_segmentation.png
#   inflating: dataset/masks/ISIC_0029588_segmentation.png
#   inflating: dataset/masks/ISIC_0029589_segmentation.png
#   inflating: dataset/masks/ISIC_0029590_segmentation.png
#   inflating: dataset/masks/ISIC_0029591_segmentation.png
#   inflating: dataset/masks/ISIC_0029592_segmentation.png
#   inflating: dataset/masks/ISIC_0029593_segmentation.png
#   inflating: dataset/masks/ISIC_0029594_segmentation.png
#   inflating: dataset/masks/ISIC_0029595_segmentation.png
#   inflating: dataset/masks/ISIC_0029596_segmentation.png
#   inflating: dataset/masks/ISIC_0029597_segmentation.png
#   inflating: dataset/masks/ISIC_0029598_segmentation.png
#   inflating: dataset/masks/ISIC_0029599_segmentation.png
#   inflating: dataset/masks/ISIC_0029600_segmentation.png
#   inflating: dataset/masks/ISIC_0029601_segmentation.png
#   inflating: dataset/masks/ISIC_0029602_segmentation.png
#   inflating: dataset/masks/ISIC_0029603_segmentation.png
#   inflating: dataset/masks/ISIC_0029604_segmentation.png
#   inflating: dataset/masks/ISIC_0029605_segmentation.png
#   inflating: dataset/masks/ISIC_0029606_segmentation.png
#   inflating: dataset/masks/ISIC_0029607_segmentation.png
#   inflating: dataset/masks/ISIC_0029608_segmentation.png
#   inflating: dataset/masks/ISIC_0029609_segmentation.png
#   inflating: dataset/masks/ISIC_0029610_segmentation.png
#   inflating: dataset/masks/ISIC_0029611_segmentation.png
#   inflating: dataset/masks/ISIC_0029612_segmentation.png
#   inflating: dataset/masks/ISIC_0029613_segmentation.png
#   inflating: dataset/masks/ISIC_0029614_segmentation.png
#   inflating: dataset/masks/ISIC_0029615_segmentation.png
#   inflating: dataset/masks/ISIC_0029616_segmentation.png
#   inflating: dataset/masks/ISIC_0029617_segmentation.png
#   inflating: dataset/masks/ISIC_0029618_segmentation.png
#   inflating: dataset/masks/ISIC_0029619_segmentation.png
#   inflating: dataset/masks/ISIC_0029620_segmentation.png
#   inflating: dataset/masks/ISIC_0029621_segmentation.png
#   inflating: dataset/masks/ISIC_0029622_segmentation.png
#   inflating: dataset/masks/ISIC_0029623_segmentation.png
#   inflating: dataset/masks/ISIC_0029624_segmentation.png
#   inflating: dataset/masks/ISIC_0029625_segmentation.png
#   inflating: dataset/masks/ISIC_0029626_segmentation.png
#   inflating: dataset/masks/ISIC_0029627_segmentation.png
#   inflating: dataset/masks/ISIC_0029628_segmentation.png
#   inflating: dataset/masks/ISIC_0029629_segmentation.png
#   inflating: dataset/masks/ISIC_0029630_segmentation.png
#   inflating: dataset/masks/ISIC_0029631_segmentation.png
#   inflating: dataset/masks/ISIC_0029632_segmentation.png
#   inflating: dataset/masks/ISIC_0029633_segmentation.png
#   inflating: dataset/masks/ISIC_0029634_segmentation.png
#   inflating: dataset/masks/ISIC_0029635_segmentation.png
#   inflating: dataset/masks/ISIC_0029636_segmentation.png
#   inflating: dataset/masks/ISIC_0029637_segmentation.png
#   inflating: dataset/masks/ISIC_0029638_segmentation.png
#   inflating: dataset/masks/ISIC_0029639_segmentation.png
#   inflating: dataset/masks/ISIC_0029640_segmentation.png
#   inflating: dataset/masks/ISIC_0029641_segmentation.png
#   inflating: dataset/masks/ISIC_0029642_segmentation.png
#   inflating: dataset/masks/ISIC_0029643_segmentation.png
#   inflating: dataset/masks/ISIC_0029644_segmentation.png
#   inflating: dataset/masks/ISIC_0029645_segmentation.png
#   inflating: dataset/masks/ISIC_0029646_segmentation.png
#   inflating: dataset/masks/ISIC_0029647_segmentation.png
#   inflating: dataset/masks/ISIC_0029648_segmentation.png
#   inflating: dataset/masks/ISIC_0029649_segmentation.png
#   inflating: dataset/masks/ISIC_0029650_segmentation.png
#   inflating: dataset/masks/ISIC_0029651_segmentation.png
#   inflating: dataset/masks/ISIC_0029652_segmentation.png
#   inflating: dataset/masks/ISIC_0029653_segmentation.png
#   inflating: dataset/masks/ISIC_0029654_segmentation.png
#   inflating: dataset/masks/ISIC_0029655_segmentation.png
#   inflating: dataset/masks/ISIC_0029656_segmentation.png
#   inflating: dataset/masks/ISIC_0029657_segmentation.png
#   inflating: dataset/masks/ISIC_0029658_segmentation.png
#   inflating: dataset/masks/ISIC_0029659_segmentation.png
#   inflating: dataset/masks/ISIC_0029660_segmentation.png
#   inflating: dataset/masks/ISIC_0029661_segmentation.png
#   inflating: dataset/masks/ISIC_0029662_segmentation.png
#   inflating: dataset/masks/ISIC_0029663_segmentation.png
#   inflating: dataset/masks/ISIC_0029664_segmentation.png
#   inflating: dataset/masks/ISIC_0029665_segmentation.png
#   inflating: dataset/masks/ISIC_0029666_segmentation.png
#   inflating: dataset/masks/ISIC_0029667_segmentation.png
#   inflating: dataset/masks/ISIC_0029668_segmentation.png
#   inflating: dataset/masks/ISIC_0029669_segmentation.png
#   inflating: dataset/masks/ISIC_0029670_segmentation.png
#   inflating: dataset/masks/ISIC_0029671_segmentation.png
#   inflating: dataset/masks/ISIC_0029672_segmentation.png
#   inflating: dataset/masks/ISIC_0029673_segmentation.png
#   inflating: dataset/masks/ISIC_0029674_segmentation.png
#   inflating: dataset/masks/ISIC_0029675_segmentation.png
#   inflating: dataset/masks/ISIC_0029676_segmentation.png
#   inflating: dataset/masks/ISIC_0029677_segmentation.png
#   inflating: dataset/masks/ISIC_0029678_segmentation.png
#   inflating: dataset/masks/ISIC_0029679_segmentation.png
#   inflating: dataset/masks/ISIC_0029680_segmentation.png
#   inflating: dataset/masks/ISIC_0029681_segmentation.png
#   inflating: dataset/masks/ISIC_0029682_segmentation.png
#   inflating: dataset/masks/ISIC_0029683_segmentation.png
#   inflating: dataset/masks/ISIC_0029684_segmentation.png
#   inflating: dataset/masks/ISIC_0029685_segmentation.png
#   inflating: dataset/masks/ISIC_0029686_segmentation.png
#   inflating: dataset/masks/ISIC_0029687_segmentation.png
#   inflating: dataset/masks/ISIC_0029688_segmentation.png
#   inflating: dataset/masks/ISIC_0029689_segmentation.png
#   inflating: dataset/masks/ISIC_0029690_segmentation.png
#   inflating: dataset/masks/ISIC_0029691_segmentation.png
#   inflating: dataset/masks/ISIC_0029692_segmentation.png
#   inflating: dataset/masks/ISIC_0029693_segmentation.png
#   inflating: dataset/masks/ISIC_0029694_segmentation.png
#   inflating: dataset/masks/ISIC_0029695_segmentation.png
#   inflating: dataset/masks/ISIC_0029696_segmentation.png
#   inflating: dataset/masks/ISIC_0029697_segmentation.png
#   inflating: dataset/masks/ISIC_0029698_segmentation.png
#   inflating: dataset/masks/ISIC_0029699_segmentation.png
#   inflating: dataset/masks/ISIC_0029700_segmentation.png
#   inflating: dataset/masks/ISIC_0029701_segmentation.png
#   inflating: dataset/masks/ISIC_0029702_segmentation.png
#   inflating: dataset/masks/ISIC_0029703_segmentation.png
#   inflating: dataset/masks/ISIC_0029704_segmentation.png
#   inflating: dataset/masks/ISIC_0029705_segmentation.png
#   inflating: dataset/masks/ISIC_0029706_segmentation.png
#   inflating: dataset/masks/ISIC_0029707_segmentation.png
#   inflating: dataset/masks/ISIC_0029708_segmentation.png
#   inflating: dataset/masks/ISIC_0029709_segmentation.png
#   inflating: dataset/masks/ISIC_0029710_segmentation.png
#   inflating: dataset/masks/ISIC_0029711_segmentation.png
#   inflating: dataset/masks/ISIC_0029712_segmentation.png
#   inflating: dataset/masks/ISIC_0029713_segmentation.png
#   inflating: dataset/masks/ISIC_0029714_segmentation.png
#   inflating: dataset/masks/ISIC_0029715_segmentation.png
#   inflating: dataset/masks/ISIC_0029716_segmentation.png
#   inflating: dataset/masks/ISIC_0029717_segmentation.png
#   inflating: dataset/masks/ISIC_0029718_segmentation.png
#   inflating: dataset/masks/ISIC_0029719_segmentation.png
#   inflating: dataset/masks/ISIC_0029720_segmentation.png
#   inflating: dataset/masks/ISIC_0029721_segmentation.png
#   inflating: dataset/masks/ISIC_0029722_segmentation.png
#   inflating: dataset/masks/ISIC_0029723_segmentation.png
#   inflating: dataset/masks/ISIC_0029724_segmentation.png
#   inflating: dataset/masks/ISIC_0029725_segmentation.png
#   inflating: dataset/masks/ISIC_0029726_segmentation.png
#   inflating: dataset/masks/ISIC_0029727_segmentation.png
#   inflating: dataset/masks/ISIC_0029728_segmentation.png
#   inflating: dataset/masks/ISIC_0029729_segmentation.png
#   inflating: dataset/masks/ISIC_0029730_segmentation.png
#   inflating: dataset/masks/ISIC_0029731_segmentation.png
#   inflating: dataset/masks/ISIC_0029732_segmentation.png
#   inflating: dataset/masks/ISIC_0029733_segmentation.png
#   inflating: dataset/masks/ISIC_0029734_segmentation.png
#   inflating: dataset/masks/ISIC_0029735_segmentation.png
#   inflating: dataset/masks/ISIC_0029736_segmentation.png
#   inflating: dataset/masks/ISIC_0029737_segmentation.png
#   inflating: dataset/masks/ISIC_0029738_segmentation.png
#   inflating: dataset/masks/ISIC_0029739_segmentation.png
#   inflating: dataset/masks/ISIC_0029740_segmentation.png
#   inflating: dataset/masks/ISIC_0029741_segmentation.png
#   inflating: dataset/masks/ISIC_0029742_segmentation.png
#   inflating: dataset/masks/ISIC_0029743_segmentation.png
#   inflating: dataset/masks/ISIC_0029744_segmentation.png
#   inflating: dataset/masks/ISIC_0029745_segmentation.png
#   inflating: dataset/masks/ISIC_0029746_segmentation.png
#   inflating: dataset/masks/ISIC_0029747_segmentation.png
#   inflating: dataset/masks/ISIC_0029748_segmentation.png
#   inflating: dataset/masks/ISIC_0029749_segmentation.png
#   inflating: dataset/masks/ISIC_0029750_segmentation.png
#   inflating: dataset/masks/ISIC_0029751_segmentation.png
#   inflating: dataset/masks/ISIC_0029752_segmentation.png
#   inflating: dataset/masks/ISIC_0029753_segmentation.png
#   inflating: dataset/masks/ISIC_0029754_segmentation.png
#   inflating: dataset/masks/ISIC_0029755_segmentation.png
#   inflating: dataset/masks/ISIC_0029756_segmentation.png
#   inflating: dataset/masks/ISIC_0029757_segmentation.png
#   inflating: dataset/masks/ISIC_0029758_segmentation.png
#   inflating: dataset/masks/ISIC_0029759_segmentation.png
#   inflating: dataset/masks/ISIC_0029760_segmentation.png
#   inflating: dataset/masks/ISIC_0029761_segmentation.png
#   inflating: dataset/masks/ISIC_0029762_segmentation.png
#   inflating: dataset/masks/ISIC_0029763_segmentation.png
#   inflating: dataset/masks/ISIC_0029764_segmentation.png
#   inflating: dataset/masks/ISIC_0029765_segmentation.png
#   inflating: dataset/masks/ISIC_0029766_segmentation.png
#   inflating: dataset/masks/ISIC_0029767_segmentation.png
#   inflating: dataset/masks/ISIC_0029768_segmentation.png
#   inflating: dataset/masks/ISIC_0029769_segmentation.png
#   inflating: dataset/masks/ISIC_0029770_segmentation.png
#   inflating: dataset/masks/ISIC_0029771_segmentation.png
#   inflating: dataset/masks/ISIC_0029772_segmentation.png
#   inflating: dataset/masks/ISIC_0029773_segmentation.png
#   inflating: dataset/masks/ISIC_0029774_segmentation.png
#   inflating: dataset/masks/ISIC_0029775_segmentation.png
#   inflating: dataset/masks/ISIC_0029776_segmentation.png
#   inflating: dataset/masks/ISIC_0029777_segmentation.png
#   inflating: dataset/masks/ISIC_0029778_segmentation.png
#   inflating: dataset/masks/ISIC_0029779_segmentation.png
#   inflating: dataset/masks/ISIC_0029780_segmentation.png
#   inflating: dataset/masks/ISIC_0029781_segmentation.png
#   inflating: dataset/masks/ISIC_0029782_segmentation.png
#   inflating: dataset/masks/ISIC_0029783_segmentation.png
#   inflating: dataset/masks/ISIC_0029784_segmentation.png
#   inflating: dataset/masks/ISIC_0029785_segmentation.png
#   inflating: dataset/masks/ISIC_0029786_segmentation.png
#   inflating: dataset/masks/ISIC_0029787_segmentation.png
#   inflating: dataset/masks/ISIC_0029788_segmentation.png
#   inflating: dataset/masks/ISIC_0029789_segmentation.png
#   inflating: dataset/masks/ISIC_0029790_segmentation.png
#   inflating: dataset/masks/ISIC_0029791_segmentation.png
#   inflating: dataset/masks/ISIC_0029792_segmentation.png
#   inflating: dataset/masks/ISIC_0029793_segmentation.png
#   inflating: dataset/masks/ISIC_0029794_segmentation.png
#   inflating: dataset/masks/ISIC_0029795_segmentation.png
#   inflating: dataset/masks/ISIC_0029796_segmentation.png
#   inflating: dataset/masks/ISIC_0029797_segmentation.png
#   inflating: dataset/masks/ISIC_0029798_segmentation.png
#   inflating: dataset/masks/ISIC_0029799_segmentation.png
#   inflating: dataset/masks/ISIC_0029800_segmentation.png
#   inflating: dataset/masks/ISIC_0029801_segmentation.png
#   inflating: dataset/masks/ISIC_0029802_segmentation.png
#   inflating: dataset/masks/ISIC_0029803_segmentation.png
#   inflating: dataset/masks/ISIC_0029804_segmentation.png
#   inflating: dataset/masks/ISIC_0029805_segmentation.png
#   inflating: dataset/masks/ISIC_0029806_segmentation.png
#   inflating: dataset/masks/ISIC_0029807_segmentation.png
#   inflating: dataset/masks/ISIC_0029808_segmentation.png
#   inflating: dataset/masks/ISIC_0029809_segmentation.png
#   inflating: dataset/masks/ISIC_0029810_segmentation.png
#   inflating: dataset/masks/ISIC_0029811_segmentation.png
#   inflating: dataset/masks/ISIC_0029812_segmentation.png
#   inflating: dataset/masks/ISIC_0029813_segmentation.png
#   inflating: dataset/masks/ISIC_0029814_segmentation.png
#   inflating: dataset/masks/ISIC_0029815_segmentation.png
#   inflating: dataset/masks/ISIC_0029816_segmentation.png
#   inflating: dataset/masks/ISIC_0029817_segmentation.png
#   inflating: dataset/masks/ISIC_0029818_segmentation.png
#   inflating: dataset/masks/ISIC_0029819_segmentation.png
#   inflating: dataset/masks/ISIC_0029820_segmentation.png
#   inflating: dataset/masks/ISIC_0029821_segmentation.png
#   inflating: dataset/masks/ISIC_0029822_segmentation.png
#   inflating: dataset/masks/ISIC_0029823_segmentation.png
#   inflating: dataset/masks/ISIC_0029824_segmentation.png
#   inflating: dataset/masks/ISIC_0029825_segmentation.png
#   inflating: dataset/masks/ISIC_0029826_segmentation.png
#   inflating: dataset/masks/ISIC_0029827_segmentation.png
#   inflating: dataset/masks/ISIC_0029828_segmentation.png
#   inflating: dataset/masks/ISIC_0029829_segmentation.png
#   inflating: dataset/masks/ISIC_0029830_segmentation.png
#   inflating: dataset/masks/ISIC_0029831_segmentation.png
#   inflating: dataset/masks/ISIC_0029832_segmentation.png
#   inflating: dataset/masks/ISIC_0029833_segmentation.png
#   inflating: dataset/masks/ISIC_0029834_segmentation.png
#   inflating: dataset/masks/ISIC_0029835_segmentation.png
#   inflating: dataset/masks/ISIC_0029836_segmentation.png
#   inflating: dataset/masks/ISIC_0029837_segmentation.png
#   inflating: dataset/masks/ISIC_0029838_segmentation.png
#   inflating: dataset/masks/ISIC_0029839_segmentation.png
#   inflating: dataset/masks/ISIC_0029840_segmentation.png
#   inflating: dataset/masks/ISIC_0029841_segmentation.png
#   inflating: dataset/masks/ISIC_0029842_segmentation.png
#   inflating: dataset/masks/ISIC_0029843_segmentation.png
#   inflating: dataset/masks/ISIC_0029844_segmentation.png
#   inflating: dataset/masks/ISIC_0029845_segmentation.png
#   inflating: dataset/masks/ISIC_0029846_segmentation.png
#   inflating: dataset/masks/ISIC_0029847_segmentation.png
#   inflating: dataset/masks/ISIC_0029848_segmentation.png
#   inflating: dataset/masks/ISIC_0029849_segmentation.png
#   inflating: dataset/masks/ISIC_0029850_segmentation.png
#   inflating: dataset/masks/ISIC_0029851_segmentation.png
#   inflating: dataset/masks/ISIC_0029852_segmentation.png
#   inflating: dataset/masks/ISIC_0029853_segmentation.png
#   inflating: dataset/masks/ISIC_0029854_segmentation.png
#   inflating: dataset/masks/ISIC_0029855_segmentation.png
#   inflating: dataset/masks/ISIC_0029856_segmentation.png
#   inflating: dataset/masks/ISIC_0029857_segmentation.png
#   inflating: dataset/masks/ISIC_0029858_segmentation.png
#   inflating: dataset/masks/ISIC_0029859_segmentation.png
#   inflating: dataset/masks/ISIC_0029860_segmentation.png
#   inflating: dataset/masks/ISIC_0029861_segmentation.png
#   inflating: dataset/masks/ISIC_0029862_segmentation.png
#   inflating: dataset/masks/ISIC_0029863_segmentation.png
#   inflating: dataset/masks/ISIC_0029864_segmentation.png
#   inflating: dataset/masks/ISIC_0029865_segmentation.png
#   inflating: dataset/masks/ISIC_0029866_segmentation.png
#   inflating: dataset/masks/ISIC_0029867_segmentation.png
#   inflating: dataset/masks/ISIC_0029868_segmentation.png
#   inflating: dataset/masks/ISIC_0029869_segmentation.png
#   inflating: dataset/masks/ISIC_0029870_segmentation.png
#   inflating: dataset/masks/ISIC_0029871_segmentation.png
#   inflating: dataset/masks/ISIC_0029872_segmentation.png
#   inflating: dataset/masks/ISIC_0029873_segmentation.png
#   inflating: dataset/masks/ISIC_0029874_segmentation.png
#   inflating: dataset/masks/ISIC_0029875_segmentation.png
#   inflating: dataset/masks/ISIC_0029876_segmentation.png
#   inflating: dataset/masks/ISIC_0029877_segmentation.png
#   inflating: dataset/masks/ISIC_0029878_segmentation.png
#   inflating: dataset/masks/ISIC_0029879_segmentation.png
#   inflating: dataset/masks/ISIC_0029880_segmentation.png
#   inflating: dataset/masks/ISIC_0029881_segmentation.png
#   inflating: dataset/masks/ISIC_0029882_segmentation.png
#   inflating: dataset/masks/ISIC_0029883_segmentation.png
#   inflating: dataset/masks/ISIC_0029884_segmentation.png
#   inflating: dataset/masks/ISIC_0029885_segmentation.png
#   inflating: dataset/masks/ISIC_0029886_segmentation.png
#   inflating: dataset/masks/ISIC_0029887_segmentation.png
#   inflating: dataset/masks/ISIC_0029888_segmentation.png
#   inflating: dataset/masks/ISIC_0029889_segmentation.png
#   inflating: dataset/masks/ISIC_0029890_segmentation.png
#   inflating: dataset/masks/ISIC_0029891_segmentation.png
#   inflating: dataset/masks/ISIC_0029892_segmentation.png
#   inflating: dataset/masks/ISIC_0029893_segmentation.png
#   inflating: dataset/masks/ISIC_0029894_segmentation.png
#   inflating: dataset/masks/ISIC_0029895_segmentation.png
#   inflating: dataset/masks/ISIC_0029896_segmentation.png
#   inflating: dataset/masks/ISIC_0029897_segmentation.png
#   inflating: dataset/masks/ISIC_0029898_segmentation.png
#   inflating: dataset/masks/ISIC_0029899_segmentation.png
#   inflating: dataset/masks/ISIC_0029900_segmentation.png
#   inflating: dataset/masks/ISIC_0029901_segmentation.png
#   inflating: dataset/masks/ISIC_0029902_segmentation.png
#   inflating: dataset/masks/ISIC_0029903_segmentation.png
#   inflating: dataset/masks/ISIC_0029904_segmentation.png
#   inflating: dataset/masks/ISIC_0029905_segmentation.png
#   inflating: dataset/masks/ISIC_0029906_segmentation.png
#   inflating: dataset/masks/ISIC_0029907_segmentation.png
#   inflating: dataset/masks/ISIC_0029908_segmentation.png
#   inflating: dataset/masks/ISIC_0029909_segmentation.png
#   inflating: dataset/masks/ISIC_0029910_segmentation.png
#   inflating: dataset/masks/ISIC_0029911_segmentation.png
#   inflating: dataset/masks/ISIC_0029912_segmentation.png
#   inflating: dataset/masks/ISIC_0029913_segmentation.png
#   inflating: dataset/masks/ISIC_0029914_segmentation.png
#   inflating: dataset/masks/ISIC_0029915_segmentation.png
#   inflating: dataset/masks/ISIC_0029916_segmentation.png
#   inflating: dataset/masks/ISIC_0029917_segmentation.png
#   inflating: dataset/masks/ISIC_0029918_segmentation.png
#   inflating: dataset/masks/ISIC_0029919_segmentation.png
#   inflating: dataset/masks/ISIC_0029920_segmentation.png
#   inflating: dataset/masks/ISIC_0029921_segmentation.png
#   inflating: dataset/masks/ISIC_0029922_segmentation.png
#   inflating: dataset/masks/ISIC_0029923_segmentation.png
#   inflating: dataset/masks/ISIC_0029924_segmentation.png
#   inflating: dataset/masks/ISIC_0029925_segmentation.png
#   inflating: dataset/masks/ISIC_0029926_segmentation.png
#   inflating: dataset/masks/ISIC_0029927_segmentation.png
#   inflating: dataset/masks/ISIC_0029928_segmentation.png
#   inflating: dataset/masks/ISIC_0029929_segmentation.png
#   inflating: dataset/masks/ISIC_0029930_segmentation.png
#   inflating: dataset/masks/ISIC_0029931_segmentation.png
#   inflating: dataset/masks/ISIC_0029932_segmentation.png
#   inflating: dataset/masks/ISIC_0029933_segmentation.png
#   inflating: dataset/masks/ISIC_0029934_segmentation.png
#   inflating: dataset/masks/ISIC_0029935_segmentation.png
#   inflating: dataset/masks/ISIC_0029936_segmentation.png
#   inflating: dataset/masks/ISIC_0029937_segmentation.png
#   inflating: dataset/masks/ISIC_0029938_segmentation.png
#   inflating: dataset/masks/ISIC_0029939_segmentation.png
#   inflating: dataset/masks/ISIC_0029940_segmentation.png
#   inflating: dataset/masks/ISIC_0029941_segmentation.png
#   inflating: dataset/masks/ISIC_0029942_segmentation.png
#   inflating: dataset/masks/ISIC_0029943_segmentation.png
#   inflating: dataset/masks/ISIC_0029944_segmentation.png
#   inflating: dataset/masks/ISIC_0029945_segmentation.png
#   inflating: dataset/masks/ISIC_0029946_segmentation.png
#   inflating: dataset/masks/ISIC_0029947_segmentation.png
#   inflating: dataset/masks/ISIC_0029948_segmentation.png
#   inflating: dataset/masks/ISIC_0029949_segmentation.png
#   inflating: dataset/masks/ISIC_0029950_segmentation.png
#   inflating: dataset/masks/ISIC_0029951_segmentation.png
#   inflating: dataset/masks/ISIC_0029952_segmentation.png
#   inflating: dataset/masks/ISIC_0029953_segmentation.png
#   inflating: dataset/masks/ISIC_0029954_segmentation.png
#   inflating: dataset/masks/ISIC_0029955_segmentation.png
#   inflating: dataset/masks/ISIC_0029956_segmentation.png
#   inflating: dataset/masks/ISIC_0029957_segmentation.png
#   inflating: dataset/masks/ISIC_0029958_segmentation.png
#   inflating: dataset/masks/ISIC_0029959_segmentation.png
#   inflating: dataset/masks/ISIC_0029960_segmentation.png
#   inflating: dataset/masks/ISIC_0029961_segmentation.png
#   inflating: dataset/masks/ISIC_0029962_segmentation.png
#   inflating: dataset/masks/ISIC_0029963_segmentation.png
#   inflating: dataset/masks/ISIC_0029964_segmentation.png
#   inflating: dataset/masks/ISIC_0029965_segmentation.png
#   inflating: dataset/masks/ISIC_0029966_segmentation.png
#   inflating: dataset/masks/ISIC_0029967_segmentation.png
#   inflating: dataset/masks/ISIC_0029968_segmentation.png
#   inflating: dataset/masks/ISIC_0029969_segmentation.png
#   inflating: dataset/masks/ISIC_0029970_segmentation.png
#   inflating: dataset/masks/ISIC_0029971_segmentation.png
#   inflating: dataset/masks/ISIC_0029972_segmentation.png
#   inflating: dataset/masks/ISIC_0029973_segmentation.png
#   inflating: dataset/masks/ISIC_0029974_segmentation.png
#   inflating: dataset/masks/ISIC_0029975_segmentation.png
#   inflating: dataset/masks/ISIC_0029976_segmentation.png
#   inflating: dataset/masks/ISIC_0029977_segmentation.png
#   inflating: dataset/masks/ISIC_0029978_segmentation.png
#   inflating: dataset/masks/ISIC_0029979_segmentation.png
#   inflating: dataset/masks/ISIC_0029980_segmentation.png
#   inflating: dataset/masks/ISIC_0029981_segmentation.png
#   inflating: dataset/masks/ISIC_0029982_segmentation.png
#   inflating: dataset/masks/ISIC_0029983_segmentation.png
#   inflating: dataset/masks/ISIC_0029984_segmentation.png
#   inflating: dataset/masks/ISIC_0029985_segmentation.png
#   inflating: dataset/masks/ISIC_0029986_segmentation.png
#   inflating: dataset/masks/ISIC_0029987_segmentation.png
#   inflating: dataset/masks/ISIC_0029988_segmentation.png
#   inflating: dataset/masks/ISIC_0029989_segmentation.png
#   inflating: dataset/masks/ISIC_0029990_segmentation.png
#   inflating: dataset/masks/ISIC_0029991_segmentation.png
#   inflating: dataset/masks/ISIC_0029992_segmentation.png
#   inflating: dataset/masks/ISIC_0029993_segmentation.png
#   inflating: dataset/masks/ISIC_0029994_segmentation.png
#   inflating: dataset/masks/ISIC_0029995_segmentation.png
#   inflating: dataset/masks/ISIC_0029996_segmentation.png
#   inflating: dataset/masks/ISIC_0029997_segmentation.png
#   inflating: dataset/masks/ISIC_0029998_segmentation.png
#   inflating: dataset/masks/ISIC_0029999_segmentation.png
#   inflating: dataset/masks/ISIC_0030000_segmentation.png
#   inflating: dataset/masks/ISIC_0030001_segmentation.png
#   inflating: dataset/masks/ISIC_0030002_segmentation.png
#   inflating: dataset/masks/ISIC_0030003_segmentation.png
#   inflating: dataset/masks/ISIC_0030004_segmentation.png
#   inflating: dataset/masks/ISIC_0030005_segmentation.png
#   inflating: dataset/masks/ISIC_0030006_segmentation.png
#   inflating: dataset/masks/ISIC_0030007_segmentation.png
#   inflating: dataset/masks/ISIC_0030008_segmentation.png
#   inflating: dataset/masks/ISIC_0030009_segmentation.png
#   inflating: dataset/masks/ISIC_0030010_segmentation.png
#   inflating: dataset/masks/ISIC_0030011_segmentation.png
#   inflating: dataset/masks/ISIC_0030012_segmentation.png
#   inflating: dataset/masks/ISIC_0030013_segmentation.png
#   inflating: dataset/masks/ISIC_0030014_segmentation.png
#   inflating: dataset/masks/ISIC_0030015_segmentation.png
#   inflating: dataset/masks/ISIC_0030016_segmentation.png
#   inflating: dataset/masks/ISIC_0030017_segmentation.png
#   inflating: dataset/masks/ISIC_0030018_segmentation.png
#   inflating: dataset/masks/ISIC_0030019_segmentation.png
#   inflating: dataset/masks/ISIC_0030020_segmentation.png
#   inflating: dataset/masks/ISIC_0030021_segmentation.png
#   inflating: dataset/masks/ISIC_0030022_segmentation.png
#   inflating: dataset/masks/ISIC_0030023_segmentation.png
#   inflating: dataset/masks/ISIC_0030024_segmentation.png
#   inflating: dataset/masks/ISIC_0030025_segmentation.png
#   inflating: dataset/masks/ISIC_0030026_segmentation.png
#   inflating: dataset/masks/ISIC_0030027_segmentation.png
#   inflating: dataset/masks/ISIC_0030028_segmentation.png
#   inflating: dataset/masks/ISIC_0030029_segmentation.png
#   inflating: dataset/masks/ISIC_0030030_segmentation.png
#   inflating: dataset/masks/ISIC_0030031_segmentation.png
#   inflating: dataset/masks/ISIC_0030032_segmentation.png
#   inflating: dataset/masks/ISIC_0030033_segmentation.png
#   inflating: dataset/masks/ISIC_0030034_segmentation.png
#   inflating: dataset/masks/ISIC_0030035_segmentation.png
#   inflating: dataset/masks/ISIC_0030036_segmentation.png
#   inflating: dataset/masks/ISIC_0030037_segmentation.png
#   inflating: dataset/masks/ISIC_0030038_segmentation.png
#   inflating: dataset/masks/ISIC_0030039_segmentation.png
#   inflating: dataset/masks/ISIC_0030040_segmentation.png
#   inflating: dataset/masks/ISIC_0030041_segmentation.png
#   inflating: dataset/masks/ISIC_0030042_segmentation.png
#   inflating: dataset/masks/ISIC_0030043_segmentation.png
#   inflating: dataset/masks/ISIC_0030044_segmentation.png
#   inflating: dataset/masks/ISIC_0030045_segmentation.png
#   inflating: dataset/masks/ISIC_0030046_segmentation.png
#   inflating: dataset/masks/ISIC_0030047_segmentation.png
#   inflating: dataset/masks/ISIC_0030048_segmentation.png
#   inflating: dataset/masks/ISIC_0030049_segmentation.png
#   inflating: dataset/masks/ISIC_0030050_segmentation.png
#   inflating: dataset/masks/ISIC_0030051_segmentation.png
#   inflating: dataset/masks/ISIC_0030052_segmentation.png
#   inflating: dataset/masks/ISIC_0030053_segmentation.png
#   inflating: dataset/masks/ISIC_0030054_segmentation.png
#   inflating: dataset/masks/ISIC_0030055_segmentation.png
#   inflating: dataset/masks/ISIC_0030056_segmentation.png
#   inflating: dataset/masks/ISIC_0030057_segmentation.png
#   inflating: dataset/masks/ISIC_0030058_segmentation.png
#   inflating: dataset/masks/ISIC_0030059_segmentation.png
#   inflating: dataset/masks/ISIC_0030060_segmentation.png
#   inflating: dataset/masks/ISIC_0030061_segmentation.png
#   inflating: dataset/masks/ISIC_0030062_segmentation.png
#   inflating: dataset/masks/ISIC_0030063_segmentation.png
#   inflating: dataset/masks/ISIC_0030064_segmentation.png
#   inflating: dataset/masks/ISIC_0030065_segmentation.png
#   inflating: dataset/masks/ISIC_0030066_segmentation.png
#   inflating: dataset/masks/ISIC_0030067_segmentation.png
#   inflating: dataset/masks/ISIC_0030068_segmentation.png
#   inflating: dataset/masks/ISIC_0030069_segmentation.png
#   inflating: dataset/masks/ISIC_0030070_segmentation.png
#   inflating: dataset/masks/ISIC_0030071_segmentation.png
#   inflating: dataset/masks/ISIC_0030072_segmentation.png
#   inflating: dataset/masks/ISIC_0030073_segmentation.png
#   inflating: dataset/masks/ISIC_0030074_segmentation.png
#   inflating: dataset/masks/ISIC_0030075_segmentation.png
#   inflating: dataset/masks/ISIC_0030076_segmentation.png
#   inflating: dataset/masks/ISIC_0030077_segmentation.png
#   inflating: dataset/masks/ISIC_0030078_segmentation.png
#   inflating: dataset/masks/ISIC_0030079_segmentation.png
#   inflating: dataset/masks/ISIC_0030080_segmentation.png
#   inflating: dataset/masks/ISIC_0030081_segmentation.png
#   inflating: dataset/masks/ISIC_0030082_segmentation.png
#   inflating: dataset/masks/ISIC_0030083_segmentation.png
#   inflating: dataset/masks/ISIC_0030084_segmentation.png
#   inflating: dataset/masks/ISIC_0030085_segmentation.png
#   inflating: dataset/masks/ISIC_0030086_segmentation.png
#   inflating: dataset/masks/ISIC_0030087_segmentation.png
#   inflating: dataset/masks/ISIC_0030088_segmentation.png
#   inflating: dataset/masks/ISIC_0030089_segmentation.png
#   inflating: dataset/masks/ISIC_0030090_segmentation.png
#   inflating: dataset/masks/ISIC_0030091_segmentation.png
#   inflating: dataset/masks/ISIC_0030092_segmentation.png
#   inflating: dataset/masks/ISIC_0030093_segmentation.png
#   inflating: dataset/masks/ISIC_0030094_segmentation.png
#   inflating: dataset/masks/ISIC_0030095_segmentation.png
#   inflating: dataset/masks/ISIC_0030096_segmentation.png
#   inflating: dataset/masks/ISIC_0030097_segmentation.png
#   inflating: dataset/masks/ISIC_0030098_segmentation.png
#   inflating: dataset/masks/ISIC_0030099_segmentation.png
#   inflating: dataset/masks/ISIC_0030100_segmentation.png
#   inflating: dataset/masks/ISIC_0030101_segmentation.png
#   inflating: dataset/masks/ISIC_0030102_segmentation.png
#   inflating: dataset/masks/ISIC_0030103_segmentation.png
#   inflating: dataset/masks/ISIC_0030104_segmentation.png
#   inflating: dataset/masks/ISIC_0030105_segmentation.png
#   inflating: dataset/masks/ISIC_0030106_segmentation.png
#   inflating: dataset/masks/ISIC_0030107_segmentation.png
#   inflating: dataset/masks/ISIC_0030108_segmentation.png
#   inflating: dataset/masks/ISIC_0030109_segmentation.png
#   inflating: dataset/masks/ISIC_0030110_segmentation.png
#   inflating: dataset/masks/ISIC_0030111_segmentation.png
#   inflating: dataset/masks/ISIC_0030112_segmentation.png
#   inflating: dataset/masks/ISIC_0030113_segmentation.png
#   inflating: dataset/masks/ISIC_0030114_segmentation.png
#   inflating: dataset/masks/ISIC_0030115_segmentation.png
#   inflating: dataset/masks/ISIC_0030116_segmentation.png
#   inflating: dataset/masks/ISIC_0030117_segmentation.png
#   inflating: dataset/masks/ISIC_0030118_segmentation.png
#   inflating: dataset/masks/ISIC_0030119_segmentation.png
#   inflating: dataset/masks/ISIC_0030120_segmentation.png
#   inflating: dataset/masks/ISIC_0030121_segmentation.png
#   inflating: dataset/masks/ISIC_0030122_segmentation.png
#   inflating: dataset/masks/ISIC_0030123_segmentation.png
#   inflating: dataset/masks/ISIC_0030124_segmentation.png
#   inflating: dataset/masks/ISIC_0030125_segmentation.png
#   inflating: dataset/masks/ISIC_0030126_segmentation.png
#   inflating: dataset/masks/ISIC_0030127_segmentation.png
#   inflating: dataset/masks/ISIC_0030128_segmentation.png
#   inflating: dataset/masks/ISIC_0030129_segmentation.png
# ...
#   inflating: dataset/masks/ISIC_0034050_segmentation.png
#   inflating: dataset/masks/ISIC_0034051_segmentation.png
#   inflating: dataset/masks/ISIC_0034052_segmentation.png
#   inflating: dataset/masks/ISIC_0034053_segmentation.png
#   inflating: dataset/masks/ISIC_0034054_segmentation.png
#   inflating: dataset/masks/ISIC_0034055_segmentation.png
#   inflating: dataset/masks/ISIC_0034056_segmentation.png
#   inflating: dataset/masks/ISIC_0034057_segmentation.png
#   inflating: dataset/masks/ISIC_0034058_segmentation.png
#   inflating: dataset/masks/ISIC_0034059_segmentation.png
#   inflating: dataset/masks/ISIC_0034060_segmentation.png
#   inflating: dataset/masks/ISIC_0034061_segmentation.png
#   inflating: dataset/masks/ISIC_0034062_segmentation.png
#   inflating: dataset/masks/ISIC_0034063_segmentation.png
#   inflating: dataset/masks/ISIC_0034064_segmentation.png
#   inflating: dataset/masks/ISIC_0034065_segmentation.png
#   inflating: dataset/masks/ISIC_0034066_segmentation.png
#   inflating: dataset/masks/ISIC_0034067_segmentation.png
#   inflating: dataset/masks/ISIC_0034068_segmentation.png
#   inflating: dataset/masks/ISIC_0034069_segmentation.png
#   inflating: dataset/masks/ISIC_0034070_segmentation.png
#   inflating: dataset/masks/ISIC_0034071_segmentation.png
#   inflating: dataset/masks/ISIC_0034072_segmentation.png
#   inflating: dataset/masks/ISIC_0034073_segmentation.png
#   inflating: dataset/masks/ISIC_0034074_segmentation.png
#   inflating: dataset/masks/ISIC_0034075_segmentation.png
#   inflating: dataset/masks/ISIC_0034076_segmentation.png
#   inflating: dataset/masks/ISIC_0034077_segmentation.png
#   inflating: dataset/masks/ISIC_0034078_segmentation.png
#   inflating: dataset/masks/ISIC_0034079_segmentation.png
#   inflating: dataset/masks/ISIC_0034080_segmentation.png
#   inflating: dataset/masks/ISIC_0034081_segmentation.png
#   inflating: dataset/masks/ISIC_0034082_segmentation.png
#   inflating: dataset/masks/ISIC_0034083_segmentation.png
#   inflating: dataset/masks/ISIC_0034084_segmentation.png
#   inflating: dataset/masks/ISIC_0034085_segmentation.png
#   inflating: dataset/masks/ISIC_0034086_segmentation.png
#   inflating: dataset/masks/ISIC_0034087_segmentation.png
#   inflating: dataset/masks/ISIC_0034088_segmentation.png
#   inflating: dataset/masks/ISIC_0034089_segmentation.png
#   inflating: dataset/masks/ISIC_0034090_segmentation.png
#   inflating: dataset/masks/ISIC_0034091_segmentation.png
#   inflating: dataset/masks/ISIC_0034092_segmentation.png
#   inflating: dataset/masks/ISIC_0034093_segmentation.png
#   inflating: dataset/masks/ISIC_0034094_segmentation.png
#   inflating: dataset/masks/ISIC_0034095_segmentation.png
#   inflating: dataset/masks/ISIC_0034096_segmentation.png
#   inflating: dataset/masks/ISIC_0034097_segmentation.png
#   inflating: dataset/masks/ISIC_0034098_segmentation.png
#   inflating: dataset/masks/ISIC_0034099_segmentation.png
#   inflating: dataset/masks/ISIC_0034100_segmentation.png
#   inflating: dataset/masks/ISIC_0034101_segmentation.png
#   inflating: dataset/masks/ISIC_0034102_segmentation.png
#   inflating: dataset/masks/ISIC_0034103_segmentation.png
#   inflating: dataset/masks/ISIC_0034104_segmentation.png
#   inflating: dataset/masks/ISIC_0034105_segmentation.png
#   inflating: dataset/masks/ISIC_0034106_segmentation.png
#   inflating: dataset/masks/ISIC_0034107_segmentation.png
#   inflating: dataset/masks/ISIC_0034108_segmentation.png
#   inflating: dataset/masks/ISIC_0034109_segmentation.png
#   inflating: dataset/masks/ISIC_0034110_segmentation.png
#   inflating: dataset/masks/ISIC_0034111_segmentation.png
#   inflating: dataset/masks/ISIC_0034112_segmentation.png
#   inflating: dataset/masks/ISIC_0034113_segmentation.png
#   inflating: dataset/masks/ISIC_0034114_segmentation.png
#   inflating: dataset/masks/ISIC_0034115_segmentation.png
#   inflating: dataset/masks/ISIC_0034116_segmentation.png
#   inflating: dataset/masks/ISIC_0034117_segmentation.png
#   inflating: dataset/masks/ISIC_0034118_segmentation.png
#   inflating: dataset/masks/ISIC_0034119_segmentation.png
#   inflating: dataset/masks/ISIC_0034120_segmentation.png
#   inflating: dataset/masks/ISIC_0034121_segmentation.png
#   inflating: dataset/masks/ISIC_0034122_segmentation.png
#   inflating: dataset/masks/ISIC_0034123_segmentation.png
#   inflating: dataset/masks/ISIC_0034124_segmentation.png
#   inflating: dataset/masks/ISIC_0034125_segmentation.png
#   inflating: dataset/masks/ISIC_0034126_segmentation.png
#   inflating: dataset/masks/ISIC_0034127_segmentation.png
#   inflating: dataset/masks/ISIC_0034128_segmentation.png
#   inflating: dataset/masks/ISIC_0034129_segmentation.png
#   inflating: dataset/masks/ISIC_0034130_segmentation.png
#   inflating: dataset/masks/ISIC_0034131_segmentation.png
#   inflating: dataset/masks/ISIC_0034132_segmentation.png
#   inflating: dataset/masks/ISIC_0034133_segmentation.png
#   inflating: dataset/masks/ISIC_0034134_segmentation.png
#   inflating: dataset/masks/ISIC_0034135_segmentation.png
#   inflating: dataset/masks/ISIC_0034136_segmentation.png
#   inflating: dataset/masks/ISIC_0034137_segmentation.png
#   inflating: dataset/masks/ISIC_0034138_segmentation.png
#   inflating: dataset/masks/ISIC_0034139_segmentation.png
#   inflating: dataset/masks/ISIC_0034140_segmentation.png
#   inflating: dataset/masks/ISIC_0034141_segmentation.png
#   inflating: dataset/masks/ISIC_0034142_segmentation.png
#   inflating: dataset/masks/ISIC_0034143_segmentation.png
#   inflating: dataset/masks/ISIC_0034144_segmentation.png
#   inflating: dataset/masks/ISIC_0034145_segmentation.png
#   inflating: dataset/masks/ISIC_0034146_segmentation.png
#   inflating: dataset/masks/ISIC_0034147_segmentation.png
#   inflating: dataset/masks/ISIC_0034148_segmentation.png
#   inflating: dataset/masks/ISIC_0034149_segmentation.png
#   inflating: dataset/masks/ISIC_0034150_segmentation.png
#   inflating: dataset/masks/ISIC_0034151_segmentation.png
#   inflating: dataset/masks/ISIC_0034152_segmentation.png
#   inflating: dataset/masks/ISIC_0034153_segmentation.png
#   inflating: dataset/masks/ISIC_0034154_segmentation.png
#   inflating: dataset/masks/ISIC_0034155_segmentation.png
#   inflating: dataset/masks/ISIC_0034156_segmentation.png
#   inflating: dataset/masks/ISIC_0034157_segmentation.png
#   inflating: dataset/masks/ISIC_0034158_segmentation.png
#   inflating: dataset/masks/ISIC_0034159_segmentation.png
#   inflating: dataset/masks/ISIC_0034160_segmentation.png
#   inflating: dataset/masks/ISIC_0034161_segmentation.png
#   inflating: dataset/masks/ISIC_0034162_segmentation.png
#   inflating: dataset/masks/ISIC_0034163_segmentation.png
#   inflating: dataset/masks/ISIC_0034164_segmentation.png
#   inflating: dataset/masks/ISIC_0034165_segmentation.png
#   inflating: dataset/masks/ISIC_0034166_segmentation.png
#   inflating: dataset/masks/ISIC_0034167_segmentation.png
#   inflating: dataset/masks/ISIC_0034168_segmentation.png
#   inflating: dataset/masks/ISIC_0034169_segmentation.png
#   inflating: dataset/masks/ISIC_0034170_segmentation.png
#   inflating: dataset/masks/ISIC_0034171_segmentation.png
#   inflating: dataset/masks/ISIC_0034172_segmentation.png
#   inflating: dataset/masks/ISIC_0034173_segmentation.png
#   inflating: dataset/masks/ISIC_0034174_segmentation.png
#   inflating: dataset/masks/ISIC_0034175_segmentation.png
#   inflating: dataset/masks/ISIC_0034176_segmentation.png
#   inflating: dataset/masks/ISIC_0034177_segmentation.png
#   inflating: dataset/masks/ISIC_0034178_segmentation.png
#   inflating: dataset/masks/ISIC_0034179_segmentation.png
#   inflating: dataset/masks/ISIC_0034180_segmentation.png
#   inflating: dataset/masks/ISIC_0034181_segmentation.png
#   inflating: dataset/masks/ISIC_0034182_segmentation.png
#   inflating: dataset/masks/ISIC_0034183_segmentation.png
#   inflating: dataset/masks/ISIC_0034184_segmentation.png
#   inflating: dataset/masks/ISIC_0034185_segmentation.png
#   inflating: dataset/masks/ISIC_0034186_segmentation.png
#   inflating: dataset/masks/ISIC_0034187_segmentation.png
#   inflating: dataset/masks/ISIC_0034188_segmentation.png
#   inflating: dataset/masks/ISIC_0034189_segmentation.png
#   inflating: dataset/masks/ISIC_0034190_segmentation.png
#   inflating: dataset/masks/ISIC_0034191_segmentation.png
#   inflating: dataset/masks/ISIC_0034192_segmentation.png
#   inflating: dataset/masks/ISIC_0034193_segmentation.png
#   inflating: dataset/masks/ISIC_0034194_segmentation.png
#   inflating: dataset/masks/ISIC_0034195_segmentation.png
#   inflating: dataset/masks/ISIC_0034196_segmentation.png
#   inflating: dataset/masks/ISIC_0034197_segmentation.png
#   inflating: dataset/masks/ISIC_0034198_segmentation.png
#   inflating: dataset/masks/ISIC_0034199_segmentation.png
#   inflating: dataset/masks/ISIC_0034200_segmentation.png
#   inflating: dataset/masks/ISIC_0034201_segmentation.png
#   inflating: dataset/masks/ISIC_0034202_segmentation.png
#   inflating: dataset/masks/ISIC_0034203_segmentation.png
#   inflating: dataset/masks/ISIC_0034204_segmentation.png
#   inflating: dataset/masks/ISIC_0034205_segmentation.png
#   inflating: dataset/masks/ISIC_0034206_segmentation.png
#   inflating: dataset/masks/ISIC_0034207_segmentation.png
#   inflating: dataset/masks/ISIC_0034208_segmentation.png
#   inflating: dataset/masks/ISIC_0034209_segmentation.png
#   inflating: dataset/masks/ISIC_0034210_segmentation.png
#   inflating: dataset/masks/ISIC_0034211_segmentation.png
#   inflating: dataset/masks/ISIC_0034212_segmentation.png
#   inflating: dataset/masks/ISIC_0034213_segmentation.png
#   inflating: dataset/masks/ISIC_0034214_segmentation.png
#   inflating: dataset/masks/ISIC_0034215_segmentation.png
#   inflating: dataset/masks/ISIC_0034216_segmentation.png
#   inflating: dataset/masks/ISIC_0034217_segmentation.png
#   inflating: dataset/masks/ISIC_0034218_segmentation.png
#   inflating: dataset/masks/ISIC_0034219_segmentation.png
#   inflating: dataset/masks/ISIC_0034220_segmentation.png
#   inflating: dataset/masks/ISIC_0034221_segmentation.png
#   inflating: dataset/masks/ISIC_0034222_segmentation.png
#   inflating: dataset/masks/ISIC_0034223_segmentation.png
#   inflating: dataset/masks/ISIC_0034224_segmentation.png
#   inflating: dataset/masks/ISIC_0034225_segmentation.png
#   inflating: dataset/masks/ISIC_0034226_segmentation.png
#   inflating: dataset/masks/ISIC_0034227_segmentation.png
#   inflating: dataset/masks/ISIC_0034228_segmentation.png
#   inflating: dataset/masks/ISIC_0034229_segmentation.png
#   inflating: dataset/masks/ISIC_0034230_segmentation.png
#   inflating: dataset/masks/ISIC_0034231_segmentation.png
#   inflating: dataset/masks/ISIC_0034232_segmentation.png
#   inflating: dataset/masks/ISIC_0034233_segmentation.png
#   inflating: dataset/masks/ISIC_0034234_segmentation.png
#   inflating: dataset/masks/ISIC_0034235_segmentation.png
#   inflating: dataset/masks/ISIC_0034236_segmentation.png
#   inflating: dataset/masks/ISIC_0034237_segmentation.png
#   inflating: dataset/masks/ISIC_0034238_segmentation.png
#   inflating: dataset/masks/ISIC_0034239_segmentation.png
#   inflating: dataset/masks/ISIC_0034240_segmentation.png
#   inflating: dataset/masks/ISIC_0034241_segmentation.png
#   inflating: dataset/masks/ISIC_0034242_segmentation.png
#   inflating: dataset/masks/ISIC_0034243_segmentation.png
#   inflating: dataset/masks/ISIC_0034244_segmentation.png
#   inflating: dataset/masks/ISIC_0034245_segmentation.png
#   inflating: dataset/masks/ISIC_0034246_segmentation.png
#   inflating: dataset/masks/ISIC_0034247_segmentation.png
#   inflating: dataset/masks/ISIC_0034248_segmentation.png
#   inflating: dataset/masks/ISIC_0034249_segmentation.png
#   inflating: dataset/masks/ISIC_0034250_segmentation.png
#   inflating: dataset/masks/ISIC_0034251_segmentation.png
#   inflating: dataset/masks/ISIC_0034252_segmentation.png
#   inflating: dataset/masks/ISIC_0034253_segmentation.png
#   inflating: dataset/masks/ISIC_0034254_segmentation.png
#   inflating: dataset/masks/ISIC_0034255_segmentation.png
#   inflating: dataset/masks/ISIC_0034256_segmentation.png
#   inflating: dataset/masks/ISIC_0034257_segmentation.png
#   inflating: dataset/masks/ISIC_0034258_segmentation.png
#   inflating: dataset/masks/ISIC_0034259_segmentation.png
#   inflating: dataset/masks/ISIC_0034260_segmentation.png
#   inflating: dataset/masks/ISIC_0034261_segmentation.png
#   inflating: dataset/masks/ISIC_0034262_segmentation.png
#   inflating: dataset/masks/ISIC_0034263_segmentation.png
#   inflating: dataset/masks/ISIC_0034264_segmentation.png
#   inflating: dataset/masks/ISIC_0034265_segmentation.png
#   inflating: dataset/masks/ISIC_0034266_segmentation.png
#   inflating: dataset/masks/ISIC_0034267_segmentation.png
#   inflating: dataset/masks/ISIC_0034268_segmentation.png
#   inflating: dataset/masks/ISIC_0034269_segmentation.png
#   inflating: dataset/masks/ISIC_0034270_segmentation.png
#   inflating: dataset/masks/ISIC_0034271_segmentation.png
#   inflating: dataset/masks/ISIC_0034272_segmentation.png
#   inflating: dataset/masks/ISIC_0034273_segmentation.png
#   inflating: dataset/masks/ISIC_0034274_segmentation.png
#   inflating: dataset/masks/ISIC_0034275_segmentation.png
#   inflating: dataset/masks/ISIC_0034276_segmentation.png
#   inflating: dataset/masks/ISIC_0034277_segmentation.png
#   inflating: dataset/masks/ISIC_0034278_segmentation.png
#   inflating: dataset/masks/ISIC_0034279_segmentation.png
#   inflating: dataset/masks/ISIC_0034280_segmentation.png
#   inflating: dataset/masks/ISIC_0034281_segmentation.png
#   inflating: dataset/masks/ISIC_0034282_segmentation.png
#   inflating: dataset/masks/ISIC_0034283_segmentation.png
#   inflating: dataset/masks/ISIC_0034284_segmentation.png
#   inflating: dataset/masks/ISIC_0034285_segmentation.png
#   inflating: dataset/masks/ISIC_0034286_segmentation.png
#   inflating: dataset/masks/ISIC_0034287_segmentation.png
#   inflating: dataset/masks/ISIC_0034288_segmentation.png
#   inflating: dataset/masks/ISIC_0034289_segmentation.png
#   inflating: dataset/masks/ISIC_0034290_segmentation.png
#   inflating: dataset/masks/ISIC_0034291_segmentation.png
#   inflating: dataset/masks/ISIC_0034292_segmentation.png
#   inflating: dataset/masks/ISIC_0034293_segmentation.png
#   inflating: dataset/masks/ISIC_0034294_segmentation.png
#   inflating: dataset/masks/ISIC_0034295_segmentation.png
#   inflating: dataset/masks/ISIC_0034296_segmentation.png
#   inflating: dataset/masks/ISIC_0034297_segmentation.png
#   inflating: dataset/masks/ISIC_0034298_segmentation.png
#   inflating: dataset/masks/ISIC_0034299_segmentation.png
#   inflating: dataset/masks/ISIC_0034300_segmentation.png
#   inflating: dataset/masks/ISIC_0034301_segmentation.png
#   inflating: dataset/masks/ISIC_0034302_segmentation.png
#   inflating: dataset/masks/ISIC_0034303_segmentation.png
#   inflating: dataset/masks/ISIC_0034304_segmentation.png
#   inflating: dataset/masks/ISIC_0034305_segmentation.png
#   inflating: dataset/masks/ISIC_0034306_segmentation.png
#   inflating: dataset/masks/ISIC_0034307_segmentation.png
#   inflating: dataset/masks/ISIC_0034308_segmentation.png
#   inflating: dataset/masks/ISIC_0034309_segmentation.png
#   inflating: dataset/masks/ISIC_0034310_segmentation.png
#   inflating: dataset/masks/ISIC_0034311_segmentation.png
#   inflating: dataset/masks/ISIC_0034312_segmentation.png
#   inflating: dataset/masks/ISIC_0034313_segmentation.png
#   inflating: dataset/masks/ISIC_0034314_segmentation.png
#   inflating: dataset/masks/ISIC_0034315_segmentation.png
#   inflating: dataset/masks/ISIC_0034316_segmentation.png
#   inflating: dataset/masks/ISIC_0034317_segmentation.png
#   inflating: dataset/masks/ISIC_0034318_segmentation.png
#   inflating: dataset/masks/ISIC_0034319_segmentation.png
#   inflating: dataset/masks/ISIC_0034320_segmentation.png

# %%
DATA_PATH
# Out:
# 'c:\\Users\\Dicoding\\Documents\\my-project\\skin-cancer-segmentation\\data\\Skin-cancer-HAM10000'

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
from tqdm import tqdm_notebook, tnrange
from glob import glob
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf
from skimage.color import rgb2gray
# from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, add
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import StandardScaler, normalize
from keras_preprocessing.image import ImageDataGenerator
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
import tensorflow.keras.backend as K
from IPython.display import display
import skimage.io
from skimage import io
import keras
import tensorflow as tf
import tensorflow.keras.backend as K
from IPython.display import display

# %%
im_width = 256
im_height = 256

train_files = []
mask_files = glob('../content/dataset/masks*/*_segmentation*')

for i in mask_files:
    train_files.append(i.replace('_segmentation','').replace('/masks', '/images').replace('.png','.jpg'))

# %%
df = pd.DataFrame({"image_path": train_files, "mask_path":mask_files})

def diagnosis(mask_path):
    value = np.max(cv2.imread(mask_path))
    if value:
        return 1
    else:
        return 0

df['mask'] = df["mask_path"].apply(lambda x: diagnosis(x))
df.head()
# Out:
#                                    image_path  \
# 0  ../content/dataset/images/ISIC_0030074.jpg
# 1  ../content/dataset/images/ISIC_0029732.jpg
# 2  ../content/dataset/images/ISIC_0031025.jpg
# 3  ../content/dataset/images/ISIC_0034247.jpg
# 4  ../content/dataset/images/ISIC_0033258.jpg
#
#                                            mask_path  mask
# 0  ../content/dataset/masks/ISIC_0030074_segmenta...     1
# 1  ../content/dataset/masks/ISIC_0029732_segmenta...     1
# 2  ../content/dataset/masks/ISIC_0031025_segmenta...     1
# 3  ../content/dataset/masks/ISIC_0034247_segmenta...     1
# 4  ../content/dataset/masks/ISIC_0033258_segmenta...     1

# %%
image1 = io.imread(df.image_path[1])

image2 = io.imread(df.image_path[2])

# Show masks
mask1 = io.imread(df.mask_path[1])
     
mask2 = io.imread(df.mask_path[2])


f, axarr = plt.subplots(2,2,figsize=(20, 20))
axarr[0,0].imshow(image1)
axarr[0,0].title.set_text("skin image")
axarr[0,1].imshow(mask1,cmap='gray')
axarr[0,1].title.set_text("skin mask")
matplotlib.rcParams.update({'font.size': 22})
axarr[1,0].imshow(image2)
axarr[1,1].imshow(mask2,cmap='gray')

# %%
# def show_image(df):

#   fig, ax = plt.subplots(nrows=10, ncols=3, figsize=(20, 40))
#   count = 0
#   i = 0
#   for mask in df["mask"]:
#     if mask == 1:
#       # Show images
#       image = io.imread(df.image_path[i])
#       ax[count,0].title.set_text("Brain MRI")
#       ax[count,0].imshow(image)

#       # Show masks
#       mask = io.imread(df.mask_path[i])
#       ax[count][1].title.set_text("Mask Brain MRI")
#       ax[count][1].imshow(mask, cmap="gray")

     
#     i += 1
#     if count == 10:
#       break
#   fig.tight_layout()
#   plt.show()

# show_image(df)

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.15)
df_train, df_val = train_test_split(df_train, test_size=0.15)
print(df_train.values.shape)
print(df_val.values.shape)
print(df_test.values.shape)
# Out:
# (7235, 3)
# (1277, 3)
# (1503, 3)

# %%
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):

    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "image_path",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask_path",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255.
    mask = mask / 255.
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %%
smooth=100

def dice_coef(y_true, y_pred):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true) + K.sum(y_pred)
    return (2.0 * intersection + smooth) / (union + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    return dice_coef_loss(y_true, y_pred) + bce(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %%
IMAGE_SIZE = (256, 256)

# %%
from tensorflow.keras.layers import Reshape, ConvLSTM2D, UpSampling2D, MaxPool2D, Concatenate

def BCDU_net_D3(input_size = (256,256,1)):
    N = input_size[0]
    inputs = Input(input_size)  
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
  
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    drop3 = Dropout(0.5)(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    # D1
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)     
    conv4_1 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    drop4_1 = Dropout(0.5)(conv4_1)
    # D2
    conv4_2 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(drop4_1)     
    conv4_2 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4_2)
    conv4_2 = Dropout(0.5)(conv4_2)
    # D3
    merge_dense = concatenate([conv4_2,drop4_1], axis = 3)
    conv4_3 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge_dense)     
    conv4_3 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4_3)
    drop4_3 = Dropout(0.5)(conv4_3)

    up6 = Conv2DTranspose(256, kernel_size=2, strides=2, padding='same',kernel_initializer = 'he_normal')(drop4_3)
    up6 = BatchNormalization(axis=3)(up6)
    up6 = Activation('relu')(up6)

    x1 = Reshape(target_shape=(1, np.int32(N/4), np.int32(N/4), 256))(drop3)
    x2 = Reshape(target_shape=(1, np.int32(N/4), np.int32(N/4), 256))(up6)
    merge6  = concatenate([x1,x2], axis = 1) 
    merge6 = ConvLSTM2D(filters = 128, kernel_size=(3, 3), padding='same', return_sequences = False, go_backwards = True,kernel_initializer = 'he_normal' )(merge6)
            
    conv6 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

    up7 = Conv2DTranspose(128, kernel_size=2, strides=2, padding='same',kernel_initializer = 'he_normal')(conv6)
    up7 = BatchNormalization(axis=3)(up7)
    up7 = Activation('relu')(up7)

    x1 = Reshape(target_shape=(1, np.int32(N/2), np.int32(N/2), 128))(conv2)
    x2 = Reshape(target_shape=(1, np.int32(N/2), np.int32(N/2), 128))(up7)
    merge7  = concatenate([x1,x2], axis = 1) 
    merge7 = ConvLSTM2D(filters = 64, kernel_size=(3, 3), padding='same', return_sequences = False, go_backwards = True,kernel_initializer = 'he_normal' )(merge7)
        
    conv7 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

    up8 = Conv2DTranspose(64, kernel_size=2, strides=2, padding='same',kernel_initializer = 'he_normal')(conv7)
    up8 = BatchNormalization(axis=3)(up8)
    up8 = Activation('relu')(up8)    

    x1 = Reshape(target_shape=(1, N, N, 64))(conv1)
    x2 = Reshape(target_shape=(1, N, N, 64))(up8)
    merge8  = concatenate([x1,x2], axis = 1) 
    merge8 = ConvLSTM2D(filters = 32, kernel_size=(3, 3), padding='same', return_sequences = False, go_backwards = True,kernel_initializer = 'he_normal' )(merge8)    
    
    conv8 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    conv8 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    conv9 = Conv2D(1, 1, activation = 'sigmoid')(conv8)

    model = Model(inputs, conv9)
    model.compile(optimizer = Adam(lr = 1e-4), loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
def resblock(X, f):
    '''
    function for creating res block
    '''
    X_copy = X  #copy of input
    
    # main path
    X = Conv2D(f, kernel_size=(1,1), kernel_initializer='he_normal')(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)
    
    X = Conv2D(f, kernel_size=(3,3), padding='same', kernel_initializer='he_normal')(X)
    X = BatchNormalization()(X)
    
    # shortcut path
    X_copy = Conv2D(f, kernel_size=(1,1), kernel_initializer='he_normal')(X_copy)
    X_copy = BatchNormalization()(X_copy)
    
    # Adding the output from main path and short path together
    X = Add()([X, X_copy])
    X = Activation('relu')(X)
    
    return X

def upsample_concat(x, skip):
    '''
    funtion for upsampling image
    '''
    X = UpSampling2D((2,2))(x)
    merge = Concatenate()([X, skip])
    
    return merge

def ResUnet(input):
  X_input = Input(input) #iniating tensor of input shape

  # Stage 1
  conv_1 = Conv2D(16, 3, activation='relu', padding='same', kernel_initializer='he_normal')(X_input)
  conv_1 = BatchNormalization()(conv_1)
  conv_1 = Conv2D(16, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv_1)
  conv_1 = BatchNormalization()(conv_1)
  pool_1 = MaxPool2D((2,2))(conv_1)

  # stage 2
  conv_2 = resblock(pool_1, 32)
  pool_2 = MaxPool2D((2,2))(conv_2)

  # Stage 3
  conv_3 = resblock(pool_2, 64)
  pool_3 = MaxPool2D((2,2))(conv_3)

  # Stage 4
  conv_4 = resblock(pool_3, 128)
  pool_4 = MaxPool2D((2,2))(conv_4)

  # Stage 5 (bottle neck)
  conv_5 = resblock(pool_4, 256)

  # Upsample Stage 1
  up_1 = upsample_concat(conv_5, conv_4)
  up_1 = resblock(up_1, 128)

  # Upsample Stage 2
  up_2 = upsample_concat(up_1, conv_3)
  up_2 = resblock(up_2, 64)

  # Upsample Stage 3
  up_3 = upsample_concat(up_2, conv_2)
  up_3 = resblock(up_3, 32)

  # Upsample Stage 4
  up_4 = upsample_concat(up_3, conv_1)
  up_4 = resblock(up_4, 16)

  # final output
  out= Conv2D(1, (1,1), kernel_initializer='he_normal', padding='same', activation='sigmoid')(up_4)

  model= Model(X_input,out, name="Res_U-Net")
  
  return model

# %%
       
def unet(input_size = (256,256,1)):
    inputs = Input(input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    drop3 = Dropout(0.5)(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    drop4 = Dropout(0.5)(conv4)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop4))
    merge6 = concatenate([drop3,up6], axis = 3)
    conv6 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv2,up7], axis = 3)
    conv7 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

    up8 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv1,up8], axis = 3)
    conv8 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    conv8 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    conv9 = Conv2D(1, 1, activation = 'sigmoid')(conv8)

    model = Model(inputs,conv9)
    
    model.compile(optimizer = Adam(learning_rate = 1e-4), loss = 'binary_crossentropy', metrics = ['accuracy'])

    return model

# %%
model = BCDU_net_D3((256,256,3))

tf.keras.utils.plot_model(
    model, to_file='model.png', show_shapes=False, show_dtype=False,
    show_layer_names=True, rankdir='TB', expand_nested=False, dpi=96,
    layer_range=None
)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  147584      ['conv2d_2[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 256)  590080      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 512)  2359808     ['conv2d_6[0][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 512)  0           ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 512)  2359808     ['dropout_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 512)  2359808     ['conv2d_8[0][0]']
#
#  dropout_2 (Dropout)            (None, 32, 32, 512)  0           ['conv2d_9[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 1024  0           ['dropout_2[0][0]',
#                                 )                                 'dropout_1[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 512)  2359808     ['conv2d_10[0][0]']
#
#  dropout_3 (Dropout)            (None, 32, 32, 512)  0           ['conv2d_11[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 256)  524544     ['dropout_3[0][0]']
#  ose)
#
#  batch_normalization (BatchNorm  (None, 64, 64, 256)  1024       ['conv2d_transpose[0][0]']
#  alization)
#
#  dropout (Dropout)              (None, 64, 64, 256)  0           ['conv2d_5[0][0]']
#
#  activation (Activation)        (None, 64, 64, 256)  0           ['batch_normalization[0][0]']
#
#  reshape (Reshape)              (None, 1, 64, 64, 2  0           ['dropout[0][0]']
#                                 56)
#
#  reshape_1 (Reshape)            (None, 1, 64, 64, 2  0           ['activation[0][0]']
#                                 56)
#
#  concatenate_1 (Concatenate)    (None, 2, 64, 64, 2  0           ['reshape[0][0]',
#                                 56)                               'reshape_1[0][0]']
#
#  conv_lstm2d (ConvLSTM2D)       (None, 64, 64, 128)  1769984     ['concatenate_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 256)  295168      ['conv_lstm2d[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 256)  590080      ['conv2d_12[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 12  131200     ['conv2d_13[0][0]']
#  spose)                         8)
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 12  512        ['conv2d_transpose_1[0][0]']
#  rmalization)                   8)
#
#  activation_1 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_1[0][0]']
#                                 8)
#
#  reshape_2 (Reshape)            (None, 1, 128, 128,  0           ['conv2d_3[0][0]']
#                                  128)
#
#  reshape_3 (Reshape)            (None, 1, 128, 128,  0           ['activation_1[0][0]']
#                                  128)
#
#  concatenate_2 (Concatenate)    (None, 2, 128, 128,  0           ['reshape_2[0][0]',
#                                  128)                             'reshape_3[0][0]']
#
#  conv_lstm2d_1 (ConvLSTM2D)     (None, 128, 128, 64  442624      ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 12  73856       ['conv_lstm2d_1[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 12  147584      ['conv2d_14[0][0]']
#                                 8)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 64  32832      ['conv2d_15[0][0]']
#  spose)                         )
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 64  256        ['conv2d_transpose_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  reshape_4 (Reshape)            (None, 1, 256, 256,  0           ['conv2d_1[0][0]']
#                                  64)
#
#  reshape_5 (Reshape)            (None, 1, 256, 256,  0           ['activation_2[0][0]']
#                                  64)
#
#  concatenate_3 (Concatenate)    (None, 2, 256, 256,  0           ['reshape_4[0][0]',
#                                  64)                              'reshape_5[0][0]']
#
#  conv_lstm2d_2 (ConvLSTM2D)     (None, 256, 256, 32  110720      ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 64  18496       ['conv_lstm2d_2[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 64  36928       ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 2)  1154        ['conv2d_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 1)  3           ['conv2d_18[0][0]']
#
# ==================================================================================================
# Total params: 20,660,869
# Trainable params: 20,659,973
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
EPOCHS = 15
BATCH_SIZE = 64
learning_rate = 0.5e-3

# %%
train_generator_args = dict(rotation_range=0.1,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            vertical_flip=True,
                            fill_mode='nearest')
train_gen = train_generator(df_train, BATCH_SIZE,
                                train_generator_args,
                                target_size=IMAGE_SIZE)
    
val_gen = train_generator(df_val, BATCH_SIZE,
                                dict(),
                                target_size=IMAGE_SIZE)
    

opt = Adam(lr=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=None, amsgrad=False)
model.compile(optimizer=opt, loss=bce_dice_loss, metrics=[iou, dice_coef])

callbacks = [ModelCheckpoint('RESUNET1_skin_seg.hdf5', verbose=0, save_best_only=True),
            ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, min_lr=1e-11),
            EarlyStopping(monitor='val_loss', restore_best_weights=True, patience=15)]

history = model.fit(train_gen,
                    steps_per_epoch=len(df_train) / BATCH_SIZE, 
                    epochs=EPOCHS, 
                    callbacks=callbacks,
                    validation_data = val_gen,
                    validation_steps=len(df_val) / BATCH_SIZE)
# Out:
# Found 7235 validated image filenames.
# Found 7235 validated image filenames.
# Epoch 1/15
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)

# %%
model.save("content/unet-resnet-model.h5")

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,20))
plt.subplot(3,1,1)
plt.plot(model.history.history['loss'], 'b-', label='train_loss')
plt.plot(model.history.history['val_loss'], 'r-', label='val_loss')
plt.legend(loc='best')
plt.xlabel('epoch')
plt.title('Loss')

plt.subplot(3,1,2)
plt.plot(model.history.history['iou'], 'b-', label='train_iou')
plt.plot(model.history.history['val_iou'], 'r-', label='val_iou')
plt.legend(loc='best')
plt.xlabel('epoch')
plt.title('IoU')

plt.subplot(3,1,3)
plt.plot(model.history.history['dice_coef'], 'b-', label='train_dice_coef')
plt.plot(model.history.history['val_dice_coef'], 'r-', label='val_dice_coef')
plt.legend(loc='best')
plt.xlabel('epoch')
plt.title('Dice Coefficient')

# %%
test_gen = train_generator(df_test, BATCH_SIZE,
                                dict(),
                                target_size=IMAGE_SIZE)
results = model.evaluate(test_gen, steps=len(df_test) / BATCH_SIZE)
print("Test loss: ",results[0])
print("Test IOU: ",results[1])
print("Test Dice Coefficent: ",results[2])

# %%
for i in range(30):
    index=np.random.randint(1,len(df_test.index))
    img = cv2.imread(df_test['image_path'].iloc[index])
    img = cv2.resize(img ,IMAGE_SIZE)
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=model.predict(img)
    mask_img = cv2.imread(df_test['mask_path'].iloc[index])
    mask_img = cv2.resize(mask_img ,IMAGE_SIZE)
    mask_img = mask_img / 255
    mask_img = mask_img[np.newaxis, :, :, :]

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    plt.imshow(np.squeeze(mask_img))
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.show()

# %%
Result_df = pd.DataFrame(history.history)
Result_df.head()

# %%
Result_df.describe()

# %%
import seaborn as sns

plt.figure(figsize=(10,8))
sns.distplot(Result_df['dice_coef'], hist=True, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4});

# %%
import seaborn as sns

plt.figure(figsize=(10,8))
sns.distplot(Result_df['loss'], hist=True, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4});

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(12,8))
ax = sns.boxplot(data=Result_df, orient="h", palette="Set2")
